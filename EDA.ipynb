# %% [markdown]
# # EDA Viajando: antes vs después de la pandemia en España
# Proyecto de análisis de datos sobre la evolución de los viajes en el contexto post-pandémico en España.

# %% [markdown]
# ![camera-1130731_1280.jpg](attachment:camera-1130731_1280.jpg)

# %% [markdown]
# ## Introducción
#
# La pandemia de la COVID-19 cambió radicalmente nuestras vidas y también nuestras ganas de movernos. Durante meses, las restricciones sanitarias mantuvieron a mucha gente en casa. Pero, ¿qué pasó cuando volvimos a salir? ¿Viajamos más? ¿Lo hicimos de forma diferente? ¿Hemos recuperado nuestro espíritu viajero?
#
# Este proyecto de análisis exploratorio de datos (EDA) nace con la intención de entender cómo ha cambiado el comportamiento de los viajeros en España desde que comenzó la pandemia. Para ello, utilizaremos datos oficiales procedentes de fuentes como la Encuesta de Turismo de Residentes (ETR) y Estadística de Movimientos Turísticos en Fronteras (FRONTUR), con los que analizaremos las tendencias antes y después del año 2020.
#
# Este análisis no solo trata de números, sino también de entender cómo ha evolucionado nuestra forma de viajar. A lo largo del proyecto, exploraremos estos temas con gráficos, comparaciones y datos visuales que nos ayudarán a responder cada hipótesis de forma clara y visual.
#
# ### Prepárate para un viaje a través de los datos. ¡Empezamos!

# %% [markdown]
# ## Hipótesis
#
# Nos planteamos las siguientes preguntas clave:
#
# 1. Se viaja más despúes de la _pandemia_? Viajes de residentes antes y después de la pandemia.
#     - En España, el número de viajes ha aumentado tras la pandemia (2020).
# 2. Se viaja más por ocio que por trabajo? Motivos de viaje: _turismo_ vs _negocios_
#     - El turismo nacional de ocio ha aumentado más que los viajes por otros motivos (trabajo, estudios, etc.).
#     - Utilizar la variable «Motivo del viaje» en la ETR para segmentar.
# 3. Influyen los festivos en el número de viajes? Las estaciones (tendencias _estacionales_)?
# 4. Los españoles viajan más dentro de España o prefieren el extranejo después de la pandemia?
# 5. El turismo internacional se ha recuperado más rápidamente que el nacional.
#     - Comprobar si los turistas extranjeros regresaron en mayor número o antes que los residentes nacionales.
#     - Comparar la evolución año a año desde 2020.
# 6. Tras la pandemia, los destinos costeros se han convertido en la opción preferida.
#     - Analizar por comunidad autónoma o provincia en ETR o FRONTUR si hay más viajes hacia zonas como Andalucía, Comunidad Valenciana, Canarias, Islas Baleares, etc.
# 7.  Ciertas comunidades autónomas han experimentado un mayor crecimiento turístico.

# %% [markdown]
# ## Datos necesarios
#
# * Volumen de viajes por año: `antes`, `durante` y `después`
#
# * Segmentación de datos:
#     - país/ region
#     - mes/ año
#     - motivo del viaje: _ocio_, _trabajo_, _estudios_, _salud_, _visitas a familiares_.
#
# * Eventos relevantes:
#     - fechas clave: inicio de la pandemia, cuarentenas, levantamiento de restricciones

# %% [markdown]
# ::: center
# | Variable                | Fuente recomendada         | Detalle                                                                 |
# |-------------------------|----------------------------|-------------------------------------------------------------------------|
# | Turistas internacionales| INE – Frontur              | Número de turistas por mes, país de origen                             |
# | Turistas nacionales     | INE – Movilidad / Egatur   | Desplazamientos por provincias / gasto medio                           |
# | Gasto turístico         | INE – Egatur               | Comparar gasto antes y después de la pandemia                          |
# | Transporte de viajeros  | INE – Transporte           | Avión, tren, bus; muestra la recuperación de la movilidad              |
# | Ocupación hotelera      | INE – Coyuntura turística  | Cuántas personas se alojan, noches, origen                             |
# | Fechas relevantes COVID | BOE / medios               | Fechas de restricciones/fin de estado de alarma                        |
#
# :::

# %% [markdown]
# ## Periodos a comparar
#
# * __Antes de la pandemia__:     2018, 2019
# * __Durante pandemia__:         2020, 2021
# * __Post_pandemia__:            2022, 2023, 2024

# %% [markdown]
# ## Fuentes de datos
#
# * [__INE__](https://www.ine.es/) : tiene datos mensuales de turistas
#     - __ETR__ - Encuesta de turismo de Residentes
#     - __FRONTUR__ - Turistas Internacionales por mes
#     - __Egatur__ -Gasto turistico
# * [__Datos Abiertos del Gobierno de España__](https://datos.gob.es)
#     - redirigen a INE
# * __Webscrapping__: [calendarios laborales por anios](https://www.calendarioslaborales.com)
# * __Eurostat__: Estadísticas de transporte y turismo para la UE.

# %% [markdown]
# ## Ideas
#
# * Evolución anual del número de viajeros.
# * Comparativa 2019 vs. 2023/2024.
# * Distribución por CCAA.
# * Impacto por CCAA, nacional vs. internacional.
# * Analizar el gasto turístico. Duración media del viaje y gasto.
# * Mapas de calor por región y año
# * Comparar con otros paises.
#
# ## Referencias adicionales
# * [__Dataestur__](https://www.dataestur.es/): Plataforma que ofrece una selección de los datos más relevantes del turismo en España, con visualizaciones y cuadros de mando interactivos.
# * [text](https://datosmacro.expansion.com/comercio/turismo-internacional/espana)
# * [__EpData__](https://www.epdata.es/) : Portal que proporciona datos y gráficos sobre diversos aspectos del turismo en España, incluyendo transporte de viajeros y ocupación hotelera.
#     - [Transporte de viajeros](https://www.epdata.es/datos/transporte-viajeros-ine-datos-graficos/123/espana/106)
#     - [Ocupación hotelera](https://www.epdata.es/datos/ocupacion-hotelera-hoteles-datos-graficos/94/espana/106)

# %% [markdown]
# ## Plan de trabajo
#
# 1. __Descarga, limpieza y preparación de datos__ (eliminación de valores nulos, formato de fechas, etc.)
#     - Filtrar por anios clave: 2018, 2019
#     - Filtrar por motivos
#     - Agrupar por año -> número de viajes por turismo
# 2. __Análisis exploratorio__:
# - Analizar gráficamente la evolución del turismo tras la pandemia mediante gráficos como:
#     + Evolución de viajes turísticos (línea por año)
#     + Comparativa: antes y después de la pandemia (barras 2019 vs. 2023)
#     + Reparto por tipo de viaje (solo si tienes más motivos en el dataset)
# - Explorar las tendencias en los datos, identificar patrones y comparar los diferentes periodos.
# 3. __Interpretación y validación de las hipótesis__:
# Contestar: `¿se viaja más ahora?`
#     - ¿Se han incrementado los viajes de ocio respecto a 2019?
#     - ¿En qué año se recuperó?
#     - ¿Hay diferencia entre los viajes nacionales y los internacionales?
#     - ¿Hay algún mes o temporada que destaque?
# 3. __Visualización de resultados y conclusiones__: mediante gráficos y tablas que ilustren claramente las diferencias en los patrones de viaje antes y después de la pandemia.

# %% [markdown]
# ## Libraries & others musts

# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings("ignore")

# %%
class display(object):
    """Representador HTML de múltiples objetos"""
    template = """<div style="float: left; padding: 10px;">
    <p style='font-family:"Courier New", Courier, monospace'>{0}</p>{1}
    </div>"""
    def __init__(self, *args):
        self.args = args
        
    def _repr_html_(self):
        return '\n'.join(self.template.format(a, eval(a)._repr_html_())
                         for a in self.args)
    
    def __repr__(self):
        return '\n\n'.join(a + '\n' + repr(eval(a))
                           for a in self.args)

# %% [markdown]
# ## Datasets para el análisis

# %% [markdown]
# ### FRONTUR: extranjeros

# %% [markdown]
# #### 13864 [Número de turistas según motivo principal del viaje](https://www.ine.es/jaxiT3/Tabla.htm?t=13864&L=0)
# - Descripción: Número de visitantes no residentes que acceden a España por las distintas vías de acceso.
# - Variables: Mes, país de origen, comunidad autónoma de destino, motivo del viaje, duración de la estancia.

# %% [markdown]
# ![alt](./img/13864.png)

# %%
#  Carga 13864.csv y limpieza 

df_13864 = pd.read_csv("./data/13864(7).csv", sep=";")
display('df_13864.head()', 'df_13864.tail()')
# Out:
# df_13864.head()
#   Tipo de dato Motivo del viaje  Periodo      Total
# 0    Dato base            Total  2025M03  6.593.604
# 1    Dato base            Total  2025M02  5.397.279
# 2    Dato base            Total  2025M01  5.065.094
# 3    Dato base            Total  2024M12  5.264.375
# 4    Dato base            Total  2024M11  5.670.219
#
# df_13864.tail()
#     Tipo de dato Motivo del viaje  Periodo    Total
# 451    Dato base    Otros motivos  2016M02  423.403
# 452    Dato base    Otros motivos  2016M01  506.662
# 453    Dato base    Otros motivos  2015M12  579.120
# 454    Dato base    Otros motivos  2015M11  435.490
# 455    Dato base    Otros motivos  2015M10  651.685

# %%
df_13864[114:]
# Out:
#     Tipo de dato           Motivo del viaje  Periodo      Total
# 114    Dato base  Ocio, recreo y vacaciones  2025M03  5.306.743
# 115    Dato base  Ocio, recreo y vacaciones  2025M02  4.422.360
# 116    Dato base  Ocio, recreo y vacaciones  2025M01  4.119.870
# 117    Dato base  Ocio, recreo y vacaciones  2024M12  4.257.518
# 118    Dato base  Ocio, recreo y vacaciones  2024M11  4.622.268
# ..           ...                        ...      ...        ...
# 451    Dato base              Otros motivos  2016M02    423.403
# 452    Dato base              Otros motivos  2016M01    506.662
# 453    Dato base              Otros motivos  2015M12    579.120
# 454    Dato base              Otros motivos  2015M11    435.490
# 455    Dato base              Otros motivos  2015M10    651.685
#
# [342 rows x 4 columns]

# %%
df_13864['Tipo de dato'].unique()
# Out:
# array(['Dato base'], dtype=object)

# %%
# Eliminamos la columna 'Tipo de dato' dado que no aporta información
df_13864 = df_13864.drop('Tipo de dato', axis=1)
df_13864.head()
# Out:
#   Motivo del viaje  Periodo      Total
# 0            Total  2025M03  6.593.604
# 1            Total  2025M02  5.397.279
# 2            Total  2025M01  5.065.094
# 3            Total  2024M12  5.264.375
# 4            Total  2024M11  5.670.219

# %%
df_pivot_13864 = df_13864.pivot(index='Periodo', columns='Motivo del viaje', values='Total').reset_index()
df_pivot_13864.head()
# Out:
# Motivo del viaje  Periodo Negocio, motivos profesionales  \
# 0                 2015M10                        469.568
# 1                 2015M11                        393.014
# 2                 2015M12                        301.888
# 3                 2016M01                        347.876
# 4                 2016M02                        441.059
#
# Motivo del viaje Ocio, recreo y vacaciones Otros motivos      Total
# 0                                5.311.088       651.685  6.432.341
# 1                                2.926.298       435.490  3.754.802
# 2                                2.631.906       579.120  3.512.914
# 3                                2.671.999       506.662  3.526.537
# 4                                2.814.264       423.403  3.678.726

# %%
df_pivot_13864.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 114 entries, 0 to 113
# Data columns (total 5 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Periodo                         114 non-null    object
#  1   Negocio, motivos profesionales  114 non-null    object
#  2   Ocio, recreo y vacaciones       114 non-null    object
#  3   Otros motivos                   114 non-null    object
#  4   Total                           114 non-null    object
# dtypes: object(5)
# memory usage: 4.6+ KB

# %%
df_pivot_13864.index
# Out:
# RangeIndex(start=0, stop=114, step=1)

# %%
df_pivot_13864.index.name

# %%
# checkpoint
df_pivot_13864[df_pivot_13864['Periodo'].str.startswith('2015')]
# Out:
# Motivo del viaje  Periodo Negocio, motivos profesionales  \
# 0                 2015M10                        469.568
# 1                 2015M11                        393.014
# 2                 2015M12                        301.888
#
# Motivo del viaje Ocio, recreo y vacaciones Otros motivos      Total
# 0                                5.311.088       651.685  6.432.341
# 1                                2.926.298       435.490  3.754.802
# 2                                2.631.906       579.120  3.512.914

# %%
df_pivot_13864.columns.values
# Out:
# array(['Periodo', 'Negocio, motivos profesionales',
#        'Ocio, recreo y vacaciones', 'Otros motivos', 'Total'],
#       dtype=object)

# %%
# quitamos separadores de miles y convertir en numeros
df_pivot_13864 = df_pivot_13864.replace('\.', '', regex=True)

# col numericas
col_no = [ 'Negocio, motivos profesionales', 'Ocio, recreo y vacaciones', 'Otros motivos', 'Total']
df_pivot_13864[col_no] = df_pivot_13864[col_no].apply(pd.to_numeric, errors='coerce')
df_pivot_13864.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 114 entries, 0 to 113
# Data columns (total 5 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Periodo                         114 non-null    object
#  1   Negocio, motivos profesionales  114 non-null    int64
#  2   Ocio, recreo y vacaciones       114 non-null    int64
#  3   Otros motivos                   114 non-null    int64
#  4   Total                           114 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 4.6+ KB

# %%
# checkpoint OK
df_pivot_13864['Ocio, recreo y vacaciones'].sum()
# Out:
# np.int64(564105996)

# %%
display("df_pivot_13864.head()", "df_pivot_13864.tail()")
# Out:
# df_pivot_13864.head()
# Motivo del viaje  Periodo  Negocio, motivos profesionales  \
# 0                 2015M10                          469568
# 1                 2015M11                          393014
# 2                 2015M12                          301888
# 3                 2016M01                          347876
# 4                 2016M02                          441059
#
# Motivo del viaje  Ocio, recreo y vacaciones  Otros motivos    Total
# 0                                   5311088         651685  6432341
# 1                                   2926298         435490  3754802
# 2                                   2631906         579120  3512914
# 3                                   2671999         506662  3526537
# 4                                   2814264         423403  3678726
#
# df_pivot_13864.tail()
# Motivo del viaje  Periodo  Negocio, motivos profesionales  \
# 109               2024M11                          463667
# 110               2024M12                          287335
# 111               2025M01                          244325
# 112               2025M02                          402453
# 113               2025M03                          561801
#
# Motivo del viaje  Ocio, recreo y vacaciones  Otros motivos    Total
# 109                                 4622268         584284  5670219
# 110                                 4257518         719521  5264375
# 111                                 4119870         700898  5065094
# 112                                 4422360         572465  5397279
# 113                                 5306743         725060  6593604

# %%
df_pivot_13864['Mes'] = df_pivot_13864.Periodo.str[-2:]
df_pivot_13864['Anio'] = df_pivot_13864['Periodo'].str[:4]
df_pivot_13864.head()
# Out:
# Motivo del viaje  Periodo  Negocio, motivos profesionales  \
# 0                 2015M10                          469568
# 1                 2015M11                          393014
# 2                 2015M12                          301888
# 3                 2016M01                          347876
# 4                 2016M02                          441059
#
# Motivo del viaje  Ocio, recreo y vacaciones  Otros motivos    Total Mes  Anio
# 0                                   5311088         651685  6432341  10  2015
# 1                                   2926298         435490  3754802  11  2015
# 2                                   2631906         579120  3512914  12  2015
# 3                                   2671999         506662  3526537  01  2016
# 4                                   2814264         423403  3678726  02  2016

# %%
nuevo_orden = ['Anio', 'Mes', 'Negocio, motivos profesionales',
       'Ocio, recreo y vacaciones', 'Otros motivos', 'Total']
df_pivot_13864 = df_pivot_13864[nuevo_orden]
df_pivot_13864
# Out:
# Motivo del viaje  Anio Mes  Negocio, motivos profesionales  \
# 0                 2015  10                          469568
# 1                 2015  11                          393014
# 2                 2015  12                          301888
# 3                 2016  01                          347876
# 4                 2016  02                          441059
# ..                 ...  ..                             ...
# 109               2024  11                          463667
# 110               2024  12                          287335
# 111               2025  01                          244325
# 112               2025  02                          402453
# 113               2025  03                          561801
#
# Motivo del viaje  Ocio, recreo y vacaciones  Otros motivos    Total
# 0                                   5311088         651685  6432341
# 1                                   2926298         435490  3754802
# 2                                   2631906         579120  3512914
# 3                                   2671999         506662  3526537
# 4                                   2814264         423403  3678726
# ..                                      ...            ...      ...
# 109                                 4622268         584284  5670219
# 110                                 4257518         719521  5264375
# 111                                 4119870         700898  5065094
# 112                                 4422360         572465  5397279
# 113                                 5306743         725060  6593604
#
# [114 rows x 6 columns]

# %%
# convierto en int tmb el año y el mes
col_no = ['Anio', 'Mes']
df_pivot_13864[col_no] = df_pivot_13864[col_no].apply(pd.to_numeric, errors='coerce')
df_pivot_13864.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 114 entries, 0 to 113
# Data columns (total 6 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Anio                            114 non-null    int64
#  1   Mes                             114 non-null    int64
#  2   Negocio, motivos profesionales  114 non-null    int64
#  3   Ocio, recreo y vacaciones       114 non-null    int64
#  4   Otros motivos                   114 non-null    int64
#  5   Total                           114 non-null    int64
# dtypes: int64(6)
# memory usage: 5.5 KB

# %%
# ordenamos descendete anio, mes
df_pivot_13864 = df_pivot_13864.sort_values(by=['Anio', 'Mes'], ascending=[False, False])
df_pivot_13864
# Out:
# Motivo del viaje  Anio  Mes  Negocio, motivos profesionales  \
# 113               2025    3                          561801
# 112               2025    2                          402453
# 111               2025    1                          244325
# 110               2024   12                          287335
# 109               2024   11                          463667
# ..                 ...  ...                             ...
# 4                 2016    2                          441059
# 3                 2016    1                          347876
# 2                 2015   12                          301888
# 1                 2015   11                          393014
# 0                 2015   10                          469568
#
# Motivo del viaje  Ocio, recreo y vacaciones  Otros motivos    Total
# 113                                 5306743         725060  6593604
# 112                                 4422360         572465  5397279
# 111                                 4119870         700898  5065094
# 110                                 4257518         719521  5264375
# 109                                 4622268         584284  5670219
# ..                                      ...            ...      ...
# 4                                   2814264         423403  3678726
# 3                                   2671999         506662  3526537
# 2                                   2631906         579120  3512914
# 1                                   2926298         435490  3754802
# 0                                   5311088         651685  6432341
#
# [114 rows x 6 columns]

# %%
df_pivot_13864.to_csv('./data/frt_13864_clean.csv')

# %% [markdown]
# ##### VIZ Echarts Viajes totales mensuales apilados por año

# %%
from ipecharts import EChartsWidget
from ipecharts.option import Option, XAxis, YAxis, Title, Tooltip, Legend
from ipecharts.option.series import Line
import pandas as pd

df = pd.read_csv('./data/frt_13864_clean.csv', index_col=0)

meses = [str(m) for m in range(1, 13)]
anios = sorted(df['Anio'].unique())

# %%
# Para cada año creamos la serie con valores ordenados por mes
series = []
colores = [
    '#80FFA5',  # verde menta suave
    '#00DDFF',  # azul celeste
    '#37A2FF',  # azul brillante
    '#FF0087',  # rosa fuerte
    '#FFBF00',  # amarillo mostaza
    '#7FFF00',  # verde chartreuse
    '#1E90FF',  # azul dodger
    '#FF4500',  # rojo anaranjado
    '#FFD700',  # dorado
    '#00FA9A',  # verde medio mar
    '#BA55D3'   # púrpura medio
]

for i, año in enumerate(anios):
    df_año = df[df['Anio'] == año].set_index('Mes')
    y_data = [int(df_año.loc[m, 'Total']) if m in df_año.index else 0 for m in range(1, 13)]

    line = Line(
        name=str(año),
        type='line',
        data=y_data,
        stack='Total',
        smooth=True,
        showSymbol=False,
        lineStyle={'width': 0},
        areaStyle={'opacity': 0.8, 'color': colores[i]}
    )
    series.append(line)

# Ejes
xAxis = XAxis(type="category", data=meses)
yAxis = YAxis(type="value")

# Opción
option = Option()
option.title = Title(text="Viajes Totales mensuales apilados por Año")
option.tooltip = Tooltip(trigger="axis")
option.legend = Legend(data=[str(a) for a in anios], top='bottom')
option.xAxis = xAxis
option.yAxis = yAxis
option.color = colores
option.series = series

# Crear widget
chart = EChartsWidget()
chart.option = option
chart
# Out:
# EChartsWidget(option=Option(angleAxis=None, aria=None, axisPointer=None, brush=None, calendar=None, color=['#8…

# %% [markdown]
# ##### VIZ Pyplot Viajes totales mensuales linear por año

# %%
import pandas as pd
import matplotlib.pyplot as plt

df_pivot_13864 = pd.read_csv('./data/frt_13864_clean.csv', index_col=0)

# Colores para las líneas
colors = [
    '#80FFA5', '#00DDFF', "#08090A", '#FF0087', '#FFBF00',
    '#7FFF00', '#1E90FF', '#FF4500', '#FFD700', '#00FA9A', '#BA55D3'
]

# Preparamos el gráfico
plt.figure(figsize=(14,8))

# mark area confinamiento
for idx, anio in enumerate(anios):
    if anio == 2020:
        start = idx - 1  # abril
        end = idx + 1    # junio
        plt.axvspan(start, end, color='red', alpha=0.1)
        break

# Agrupamos por año para trazar líneas por año
for i, (year, group) in enumerate(df_pivot_13864.groupby('Anio')):
    x = group['Mes']
    y = group['Total']
    plt.plot(x, y, label=str(year), color=colors[i], marker='o')

plt.title('Total viajes por mes y año')
plt.xlabel('Mes')
plt.ylabel('Total viajes')
plt.legend(title='Año')
plt.grid(False)
plt.xticks(range(1,13))
plt.show()

# %% [markdown]
# ##### VIZ Echarts Viajes por mes (2015–2025) con confinamiento destacado

# %%
import numpy as np
import warnings
warnings.filterwarnings("ignore")

from ipecharts import EChartsWidget
from ipecharts.option import Option, XAxis, YAxis, Title, Tooltip, Legend, Toolbox
from ipecharts.option.series import Line

df_pivot_13864['Mes'] = df_pivot_13864['Mes'].astype(str)

months = list(map(str, range(1, 13)))

colors = [
    '#80FFA5', '#00DDFF', '#37A2FF', '#FF0087', '#FFBF00',
    '#7FFF00', '#1E90FF', '#FF4500', '#FFD700', '#00FA9A', '#BA55D3'
]

series = []
legend_names = []

# Definimos el área marcada (marzo a junio)
mark_area = {
    'data': [[{'xAxis': '4'}, {'xAxis': '6'}]],
    'itemStyle': {
        'color': 'rgba(255, 173, 177, 0.2)'  # rosa claro semitransparente
    }
}

for i, year in enumerate(range(2015, 2026)):
    df_year = df_pivot_13864[df_pivot_13864['Anio'] == year]
    df_year = df_year.groupby('Mes')['Total'].sum().reindex(months, fill_value=np.nan).reset_index()

    line = Line(
        name=str(year),
        type="line",
        data=df_year['Total'].tolist(),
        smooth=True,
        showSymbol=True,
        lineStyle={'width': 2},
        areaStyle=None
    )

    # Añadimos el markArea solo al año 2020 o a la primera serie si lo quieres siempre visible
    if year == 2020:
        line.markArea = mark_area

    series.append(line)
    legend_names.append(str(year))

chart = EChartsWidget()

xAxis = XAxis(type="category", data=months)
yAxis = YAxis(type="value")

option = Option()
option.title = Title(text="Viajes por mes (2015–2025)")
option.tooltip = Tooltip(trigger="axis")
option.legend = Legend(data=legend_names, top='bottom')
option.xAxis = xAxis
option.yAxis = yAxis
option.color = colors[:len(series)]
option.series = series
option.toolbox = Toolbox(show=True, feature={"saveAsImage": {"show": True}})

chart.option = option
chart
# Out:
# EChartsWidget(option=Option(angleAxis=None, aria=None, axisPointer=None, brush=None, calendar=None, color=['#8…

# %% [markdown]
# ##### VIZ Echarts Comparación viajes por intervalos de 2 años
#
# * **Antes**: 2018 -2019
# * **Durante**: 2020 -2021
# * **Despues 1**: 2022 -2023
# * **Despues 2**: 2024 -2025

# %%
from ipecharts import EChartsWidget
from ipecharts.option import Option, XAxis, YAxis, Title, Tooltip, Legend, Toolbox
from ipecharts.option.series import Line

# Datos: meses 1-12 (string) para eje X
months = list(map(str, range(1, 13)))

# Agrupar por mes, sumando el total mensual
totales_mens_18_19 = df_pivot_13864[df_pivot_13864['Anio'].isin([2018, 2019])].groupby([ 'Mes'])['Total'].sum().reindex(months, fill_value=np.nan).reset_index()
totales_mens_20_21 = df_pivot_13864[df_pivot_13864['Anio'].isin([2020, 2021])].groupby([ 'Mes'])['Total'].sum().reindex(months, fill_value=np.nan).reset_index()
totales_mens_22_23 = df_pivot_13864[df_pivot_13864['Anio'].isin([2022, 2023])].groupby([ 'Mes'])['Total'].sum().reindex(months, fill_value=np.nan).reset_index()
totales_mens_24_25 = df_pivot_13864[df_pivot_13864['Anio'].isin([2024, 2025])].groupby([ 'Mes'])['Total'].sum().reindex(months, fill_value=np.nan).reset_index()

# Datos de cada año (por mes)
data_18_19 = totales_mens_18_19.Total.values
data_20_21 = totales_mens_20_21.Total.values
data_22_23 = totales_mens_22_23.Total.values
data_24_25 = totales_mens_24_25.Total.values

chart = EChartsWidget()

xAxis = XAxis(type="category", data=months)
yAxis = YAxis(type="value")

colors = ['#80FFA5', '#FF0087', '#00DDFF', '#37A2FF']

# Definimos el área marcada (marzo a junio)
mark_area = {
    'data': [[{'xAxis': '4'}, {'xAxis': '6'}]],
    'itemStyle': {
        'color': 'rgba(255, 173, 177, 0.2)'  # rosa claro semitransparente
    }
}

line1 = Line(name="2018-2019", type="line", data=data_18_19, smooth=True, showSymbol=True, lineStyle={'width': 2}, areaStyle=None)
line2 = Line(name="2020-2021", type="line", data=data_20_21, smooth=True, showSymbol=True, lineStyle={'width': 2}, areaStyle=None, markArea=mark_area)
line3 = Line(name="2022-2023", type="line", data=data_22_23, smooth=True, showSymbol=True, lineStyle={'width': 2}, areaStyle=None)
line4 = Line(name="2024-2025", type="line", data=data_24_25, smooth=True, showSymbol=True, lineStyle={'width': 2}, areaStyle=None)

option = Option()

option.title = Title(text="Viajes por mes y año")
option.tooltip = Tooltip(trigger="axis")
option.legend = Legend(data=["2018-2019", "2020-2021", "2022-2023", "2024-2025"], top='bottom')
option.xAxis = xAxis
option.yAxis = yAxis
option.color = colors
option.series = [line1, line2, line3, line4]
option.toolbox = Toolbox(show=True, feature={"saveAsImage": {"show": True}})

chart.option = option
chart
# Out:
# EChartsWidget(option=Option(angleAxis=None, aria=None, axisPointer=None, brush=None, calendar=None, color=['#8…

# %% [markdown]
# ##### VIZ Echarts Comparación de viajes mensual por intervalos 2 vs 3 años
#
# * **Antes**: 2018 - 2019
# * **Durante**: 2020 - 2021
# * **Despues**: 2022 - 2023 - 2024

# %%
from ipecharts import EChartsWidget
from ipecharts.option import Option, XAxis, YAxis, Title, Tooltip, Legend, Toolbox
from ipecharts.option.series import Line

# Datos: meses 1-12 (string) para eje X
months = list(map(str, range(1, 13)))

# Agrupar por mes, sumando el total mensual
totales_mens_18_19 = df_pivot_13864[df_pivot_13864['Anio'].isin([2018, 2019])].groupby([ 'Mes'])['Total'].sum().reset_index()
totales_mens_20_21 = df_pivot_13864[df_pivot_13864['Anio'].isin([2020, 2021])].groupby([ 'Mes'])['Total'].sum().reset_index()
totales_mens_22_23_24 = df_pivot_13864[df_pivot_13864['Anio'].isin([2022, 2023, 2024])].groupby([ 'Mes'])['Total'].sum().reset_index()

# Datos de cada año (por mes)
data_18_19 = totales_mens_18_19.Total.values
data_20_21 = totales_mens_20_21.Total.values
data_22_23_24 = totales_mens_22_23_24.Total.values

mark_area = {
    'data': [
        [{'xAxis': '4'}, {'xAxis': '6'}]  # Marca desde abril (5) a mayo (6)
    ],
    'itemStyle': {
        'color': 'rgba(255, 173, 177, 0.2)'
    }
}
chart = EChartsWidget()

xAxis = XAxis(type="category", data=months)
yAxis = YAxis(type="value")

colors = ['#80FFA5', '#FF0087', '#00DDFF']


line1 = Line(name="2018-2019", type="line", data=data_18_19, smooth=True, showSymbol=True, lineStyle={'width': 2}, areaStyle=None, markArea=mark_area)
line2 = Line(name="2020-2021", type="line", data=data_20_21, smooth=True, showSymbol=True, lineStyle={'width': 2}, areaStyle=None)
line3 = Line(name="2022-2023-2024", type="line", data=data_22_23_24, smooth=True, showSymbol=True, lineStyle={'width': 2}, areaStyle=None)

option = Option()
option.title = Title(text="Comparación de viajes mensual por intervalos 2 vs 3 años")
option.tooltip = Tooltip(trigger="axis")
option.legend = Legend(data=["2018-2019", "2020-2021", "2022-2023-2024"], top='bottom')
option.xAxis = xAxis
option.yAxis = yAxis
option.color = colors
option.series = [line1, line2, line3]
option.toolbox = Toolbox(show=True, feature={"saveAsImage": {"show": True}})


chart.option = option
chart
# Out:
# EChartsWidget(option=Option(angleAxis=None, aria=None, axisPointer=None, brush=None, calendar=None, color=['#8…

# %% [markdown]
# ##### VIZ Echarts Donut Distribución total de viajes por periodo

# %%
import pandas as pd
import numpy as np

df_pivot_13864.head()
# Out:
#      Anio Mes  Negocio, motivos profesionales  Ocio, recreo y vacaciones  \
# 113  2025   3                          561801                    5306743
# 112  2025   2                          402453                    4422360
# 111  2025   1                          244325                    4119870
# 110  2024  12                          287335                    4257518
# 109  2024  11                          463667                    4622268
#
#      Otros motivos    Total
# 113         725060  6593604
# 112         572465  5397279
# 111         700898  5065094
# 110         719521  5264375
# 109         584284  5670219

# %%
df_pivot_13864.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 114 entries, 113 to 0
# Data columns (total 6 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Anio                            114 non-null    int64
#  1   Mes                             114 non-null    object
#  2   Negocio, motivos profesionales  114 non-null    int64
#  3   Ocio, recreo y vacaciones       114 non-null    int64
#  4   Otros motivos                   114 non-null    int64
#  5   Total                           114 non-null    int64
# dtypes: int64(5), object(1)
# memory usage: 6.2+ KB

# %%
suma_2018_2019 = df_pivot_13864[df_pivot_13864['Anio'].isin([2018, 2019])]['Total'].sum()
suma_2020_2021 = df_pivot_13864[df_pivot_13864['Anio'].isin([2020, 2021])]['Total'].sum()
suma_2022_2023 = df_pivot_13864[df_pivot_13864['Anio'].isin([2022, 2023])]['Total'].sum()
suma_2024_2025 = df_pivot_13864[df_pivot_13864['Anio'].isin([2024, 2025])]['Total'].sum()

# %%
from ipecharts import EChartsWidget
from ipecharts.option import Option, Title, Tooltip, Legend, Toolbox
from ipecharts.option.series import Pie

data = [
    {"value": suma_2018_2019, "name": "2018–2019"},
    {"value": suma_2020_2021, "name": "2020–2021"},
    {"value": suma_2022_2023, "name": "2022–2023"},
    {"value": suma_2024_2025, "name": "2024–2025"}
]

# Colores opcionales
colors = ['#80FFA5', '#FF0087', '#00DDFF', '#37A2FF']

# Crear widget de gráfico
chart = EChartsWidget()

# Crear serie tipo "donut"
series = Pie(
    name="Viajes por periodo",
    type="pie",
    radius=["40%", "70%"],
    avoidLabelOverlap=False,
    itemStyle={
        "borderRadius": 10,
        "borderColor": "#fff",
        "borderWidth": 2
    },
    label={
        "show": True,
        "position": "inside",
        "formatter": "{d}%",
        "fontSize": 12
    },
    emphasis={
        "label": {
            "show": True,
            "fontSize": 20,
            "fontWeight": "bold"
        }
    },
    labelLine={"show": False},
    data=data
)

# Configurar opciones del gráfico
option = Option()
option.color = colors
option.title = Title(text="Distribución total de viajes por periodo", left="center")
option.tooltip = Tooltip(trigger="item", formatter="{b}: {c} ({d}%)")
option.legend = Legend(top="5%", left="center")
option.toolbox = Toolbox(show=True, feature={"saveAsImage": {"show": True}})
option.series = [series]

# Asignar opción al gráfico
chart.option = option
chart
# Out:
# EChartsWidget(option=Option(angleAxis=None, aria=None, axisPointer=None, brush=None, calendar=None, color=['#8…

# %% [markdown]
# ##### VIZ Echarts Donut por Tipo de viaje por intervalos de dos años

# %%
df_pivot_13864.head()
# Out:
#      Anio Mes  Negocio, motivos profesionales  Ocio, recreo y vacaciones  \
# 113  2025   3                          561801                    5306743
# 112  2025   2                          402453                    4422360
# 111  2025   1                          244325                    4119870
# 110  2024  12                          287335                    4257518
# 109  2024  11                          463667                    4622268
#
#      Otros motivos    Total
# 113         725060  6593604
# 112         572465  5397279
# 111         700898  5065094
# 110         719521  5264375
# 109         584284  5670219

# %%
df_pivot_13864.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 114 entries, 113 to 0
# Data columns (total 6 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Anio                            114 non-null    int64
#  1   Mes                             114 non-null    object
#  2   Negocio, motivos profesionales  114 non-null    int64
#  3   Ocio, recreo y vacaciones       114 non-null    int64
#  4   Otros motivos                   114 non-null    int64
#  5   Total                           114 non-null    int64
# dtypes: int64(5), object(1)
# memory usage: 6.2+ KB

# %%
negocio_2018_2019 = df_pivot_13864[df_pivot_13864['Anio'].isin([2018, 2019])]['Negocio, motivos profesionales'].sum()
negocio_2020_2021 = df_pivot_13864[df_pivot_13864['Anio'].isin([2020, 2021])]['Negocio, motivos profesionales'].sum()
negocio_2022_2023 = df_pivot_13864[df_pivot_13864['Anio'].isin([2022, 2023])]['Negocio, motivos profesionales'].sum()
negocio_2024_2025 = df_pivot_13864[df_pivot_13864['Anio'].isin([2024, 2025])]['Negocio, motivos profesionales'].sum()

ocio_2018_2019 = df_pivot_13864[df_pivot_13864['Anio'].isin([2018, 2019])]['Ocio, recreo y vacaciones'].sum()
ocio_2020_2021 = df_pivot_13864[df_pivot_13864['Anio'].isin([2020, 2021])]['Ocio, recreo y vacaciones'].sum()
ocio_2022_2023 = df_pivot_13864[df_pivot_13864['Anio'].isin([2022, 2023])]['Ocio, recreo y vacaciones'].sum()
ocio_2024_2025 = df_pivot_13864[df_pivot_13864['Anio'].isin([2024, 2025])]['Ocio, recreo y vacaciones'].sum()

otros_2018_2019 = df_pivot_13864[df_pivot_13864['Anio'].isin([2018, 2019])]['Otros motivos'].sum()
otros_2020_2021 = df_pivot_13864[df_pivot_13864['Anio'].isin([2020, 2021])]['Otros motivos'].sum()
otros_2022_2023 = df_pivot_13864[df_pivot_13864['Anio'].isin([2022, 2023])]['Otros motivos'].sum()
otros_2024_2025 = df_pivot_13864[df_pivot_13864['Anio'].isin([2024, 2025])]['Otros motivos'].sum()

# %%
from ipecharts import EChartsWidget
from ipecharts.option import Option, Title, Tooltip, Legend, Toolbox, Grid
from ipecharts.option.series import Pie

# Datos ya procesados
datos_motivos = {
    "Negocio": [
        {"value": negocio_2018_2019, "name": "2018–2019"},
        {"value": negocio_2020_2021, "name": "2020–2021"},
        {"value": negocio_2022_2023, "name": "2022–2023"},
        {"value": negocio_2024_2025, "name": "2024–2025"}
    ],
    "Ocio": [
        {"value": ocio_2018_2019, "name": "2018–2019"},
        {"value": ocio_2020_2021, "name": "2020–2021"},
        {"value": ocio_2022_2023, "name": "2022–2023"},
        {"value": ocio_2024_2025, "name": "2024–2025"}
    ],
    "Otros": [
        {"value": otros_2018_2019, "name": "2018–2019"},
        {"value": otros_2020_2021, "name": "2020–2021"},
        {"value": otros_2022_2023, "name": "2022–2023"},
        {"value": otros_2024_2025, "name": "2024–2025"}
    ]
}

# Crear widget de gráfico
chart = EChartsWidget()

# Colores para los períodos
colors = ['#80FFA5', '#FF0087', '#00DDFF', '#37A2FF']

# Crear lista de series para cada gráfico
series = []
for idx, (motivo, data) in enumerate(datos_motivos.items()):
    series.append(
        Pie(
            name=motivo,
            type="pie",
            radius=["30%", "60%"],
            center=[f"{(idx + 1) * 25}%", "50%"],
            avoidLabelOverlap=False,
            itemStyle={
                "borderRadius": 10,
                "borderColor": "#fff",
                "borderWidth": 2
            },
            label={
                "show": True,
                "position": "center",
                "formatter": motivo,
                "fontSize": 16,
                "fontWeight": "bold"
            },
            emphasis={
                "label": {
                    "show": True,
                    "fontSize": 16,
                    "fontWeight": "bold"
                }
            },
            labelLine={"show": False},
            data=data
        )
    )

centers = ["20%", "50%", "80%"]

# Configurar opciones del gráfico
option = Option()
option.title = Title(text="Distribución de viajes por motivo y período", left="center")
option.tooltip = Tooltip(trigger="item", formatter="{a}<br/>{b}: {c} ({d}%)")
option.legend = Legend(orient="vertical", left="left")
option.toolbox = Toolbox(show=True, feature={"saveAsImage": {"show": True}})
option.series = series
option.color = colors

# Asignar opción al gráfico
chart.option = option
chart
# Out:
# EChartsWidget(option=Option(angleAxis=None, aria=None, axisPointer=None, brush=None, calendar=None, color=['#8…

# %%
from ipecharts import EChartsWidget
from ipecharts.option import Option, Title, Tooltip, Legend, Toolbox
from ipecharts.option.series import Pie

# Datos por motivo
datos_motivos = {
    "Negocio": [
        {"value": negocio_2018_2019, "name": "2018–2019"},
        {"value": negocio_2020_2021, "name": "2020–2021"},
        {"value": negocio_2022_2023, "name": "2022–2023"},
        {"value": negocio_2024_2025, "name": "2024–2025"}
    ],
    "Ocio": [
        {"value": ocio_2018_2019, "name": "2018–2019"},
        {"value": ocio_2020_2021, "name": "2020–2021"},
        {"value": ocio_2022_2023, "name": "2022–2023"},
        {"value": ocio_2024_2025, "name": "2024–2025"}
    ],
    "Otros": [
        {"value": otros_2018_2019, "name": "2018–2019"},
        {"value": otros_2020_2021, "name": "2020–2021"},
        {"value": otros_2022_2023, "name": "2022–2023"},
        {"value": otros_2024_2025, "name": "2024–2025"}
    ]
}

# Crear widget de gráfico
chart = EChartsWidget()

# Crear las series de tipo "donut"
series = []
centers = ["20%", "50%", "80%"]
motivos = list(datos_motivos.keys())
colors = ['#80FFA5', '#FF0087', '#00DDFF', '#37A2FF']

for i, motivo in enumerate(motivos):
    series.append(
        Pie(
            name=motivo,
            type="pie",
            radius=["30%", "60%"],
            center=[centers[i], "60%"],
            avoidLabelOverlap=False,
            itemStyle={
                "borderRadius": 10,
                "borderColor": "#fff",
                "borderWidth": 2
            },
            label={
                "show": True,
                "position": "inside",
                "formatter": "{d}%",
                "fontSize": 12
            },
            emphasis={
                "label": {
                    "show": True,
                    "fontSize": 14,
                    "fontWeight": "bold"
                }
            },
            labelLine={"show": True},
            data=datos_motivos[motivo]
        )
    )

# Configurar opciones del gráfico
option = Option()
option.title = Title(text="Distribución de viajes por motivo y período", left="center", top="5%")
option.tooltip = Tooltip(trigger="item", formatter="{a}<br/>{b}: {c} ({d}%)")
option.legend = Legend(orient="vertical", left="left")
option.toolbox = Toolbox(show=True, feature={"saveAsImage": {"show": True}})
option.series = series
option.color = colors

# Asignar opción al gráfico
chart.option = option
chart
# Out:
# EChartsWidget(option=Option(angleAxis=None, aria=None, axisPointer=None, brush=None, calendar=None, color=['#8…

# %%
import pandas as pd
from ipecharts import EChartsWidget
from ipecharts.option import Option, Tooltip, Legend, Grid, XAxis, YAxis, Title
from ipecharts.option.series import Bar

# Agrupa por año y suma cada motivo
df_grouped = df_pivot_13864.groupby('Anio').agg({
    'Negocio, motivos profesionales': 'sum',
    'Ocio, recreo y vacaciones': 'sum',
    'Otros motivos': 'sum'
}).reset_index()

anios = df_grouped['Anio'].astype(str).tolist()
negocio = df_grouped['Negocio, motivos profesionales'].tolist()
ocio = df_grouped['Ocio, recreo y vacaciones'].tolist()
otros = df_grouped['Otros motivos'].tolist()

series = [
    Bar(name='Negocio', data=negocio, stack='total', label={'show': False}),
    Bar(name='Ocio', data=ocio, stack='total', label={'show': False}),
    Bar(name='Otros', data=otros, stack='total', label={'show': False}),
]

option = Option()
option.tooltip = Tooltip(trigger='axis', axisPointer={'type': 'shadow'})
option.legend = Legend(orient="horizontal", top="bottom")
option.grid = Grid(left='3%', right='4%', bottom='3%', containLabel=True)
option.xAxis = XAxis(type='value')
option.yAxis = YAxis(type='category', data=anios)
option.series = series
option.title = Title(text="Totales apilados por motivo de viaje y año", left="center")
option.toolbox = Toolbox(show=True, feature={"saveAsImage": {"show": True}})

chart = EChartsWidget()
chart.option = option
chart
# Out:
# EChartsWidget(option=Option(angleAxis=None, aria=None, axisPointer=None, brush=None, calendar=None, dataset=No…

# %% [markdown]
# #### 13884 [Resultados detallados mensuales FRONTUR](https://www.ine.es/jaxiT3/Tabla.htm?t=13884)

# %% [markdown]
# ![Img](./img/13884.png)

# %%
# # TODO: limpiar caracteres raros
# df_residentes = pd.read_csv("./data/13884.csv", sep=";")
# df_residentes.head()

# %% [markdown]
# ### ETR (Residentes, nacionales)

# %% [markdown]
# #### 12421 [Viajes, pernoctaciones, duración media y gasto por motivo principal del viaje](https://www.ine.es/jaxiT3/Tabla.htm?t=12421)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
df_12421 = pd.read_csv('./data/12421.csv', sep=';', encoding='latin-1')
display('df_12421.head()', 'df_12421.tail()')
# Out:
# df_12421.head()
#   Motivo principal Concepto turístico    Tipo de dato  Periodo       Total
# 0            Total             Viajes  Valor absoluto  2024M12  14.321.016
# 1            Total             Viajes  Valor absoluto  2024M11  11.561.861
# 2            Total             Viajes  Valor absoluto  2024M10  12.486.330
# 3            Total             Viajes  Valor absoluto  2024M09  16.101.193
# 4            Total             Viajes  Valor absoluto  2024M08  24.867.614
#
# df_12421.tail()
#     Motivo principal Concepto turístico    Tipo de dato  Periodo      Total
# 590    Otros motivos             Viajes  Valor absoluto  2015M06  1.119.341
# 591    Otros motivos             Viajes  Valor absoluto  2015M05  1.215.058
# 592    Otros motivos             Viajes  Valor absoluto  2015M04  1.065.448
# 593    Otros motivos             Viajes  Valor absoluto  2015M03    954.408
# 594    Otros motivos             Viajes  Valor absoluto  2015M02    852.383

# %%
df_12421['Tipo de dato'].nunique()
# Out:
# 1

# %%
df_12421['Concepto turístico'].nunique()
# Out:
# 1

# %%
# Eliminamos las cols dado que son valor único (Viaje, Valor absoluto) y no aportan información
df_12421 = df_12421.drop(['Tipo de dato', 'Concepto turístico'], axis=1)
df_12421.head()
# Out:
#   Motivo principal  Periodo       Total
# 0            Total  2024M12  14.321.016
# 1            Total  2024M11  11.561.861
# 2            Total  2024M10  12.486.330
# 3            Total  2024M09  16.101.193
# 4            Total  2024M08  24.867.614

# %%
df_12421['Motivo principal'].unique()
# Out:
# array(['Total', 'Ocio, recreo y vacaciones',
#        'Visitas a familiares o amigos',
#        'Negocios y otros motivos profesionales', 'Otros motivos'],
#       dtype=object)

# %%
df_pivot_12421 = df_12421.pivot(index='Periodo', columns='Motivo principal', values='Total').reset_index()
df_pivot_12421.head()
# Out:
# Motivo principal  Periodo Negocios y otros motivos profesionales  \
# 0                 2015M02                              1.501.367
# 1                 2015M03                              1.604.882
# 2                 2015M04                              1.553.530
# 3                 2015M05                              1.690.830
# 4                 2015M06                              2.152.339
#
# Motivo principal Ocio, recreo y vacaciones Otros motivos       Total  \
# 0                                3.527.378       852.383  10.134.462
# 1                                4.520.604       954.408  11.608.193
# 2                                7.546.401     1.065.448  16.336.628
# 3                                6.608.010     1.215.058  14.814.300
# 4                                7.623.671     1.119.341  15.605.072
#
# Motivo principal Visitas a familiares o amigos
# 0                                    4.253.333
# 1                                    4.528.299
# 2                                    6.171.248
# 3                                    5.300.402
# 4                                    4.709.721

# %%
# quitamos separadores de miles y convertir en numeros
df_pivot_12421 = df_pivot_12421.replace('\.', '', regex=True)

# col numericas
col_no = [ 'Negocios y otros motivos profesionales', 'Ocio, recreo y vacaciones', 'Otros motivos', 'Total', 'Visitas a familiares o amigos']
df_pivot_12421[col_no] = df_pivot_12421[col_no].apply(pd.to_numeric, errors='coerce')
df_pivot_12421.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119 entries, 0 to 118
# Data columns (total 6 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   Periodo                                 119 non-null    object
#  1   Negocios y otros motivos profesionales  119 non-null    int64
#  2   Ocio, recreo y vacaciones               118 non-null    float64
#  3   Otros motivos                           118 non-null    float64
#  4   Total                                   119 non-null    int64
#  5   Visitas a familiares o amigos           119 non-null    int64
# dtypes: float64(2), int64(3), object(1)
# memory usage: 5.7+ KB

# %%
df_pivot_12421['Mes'] = df_pivot_12421.Periodo.str[-2:]
df_pivot_12421['Anio'] = df_pivot_12421['Periodo'].str[:4]
df_pivot_12421.head()
# Out:
# Motivo principal  Periodo  Negocios y otros motivos profesionales  \
# 0                 2015M02                                 1501367
# 1                 2015M03                                 1604882
# 2                 2015M04                                 1553530
# 3                 2015M05                                 1690830
# 4                 2015M06                                 2152339
#
# Motivo principal  Ocio, recreo y vacaciones  Otros motivos     Total  \
# 0                                 3527378.0       852383.0  10134462
# 1                                 4520604.0       954408.0  11608193
# 2                                 7546401.0      1065448.0  16336628
# 3                                 6608010.0      1215058.0  14814300
# 4                                 7623671.0      1119341.0  15605072
#
# Motivo principal  Visitas a familiares o amigos Mes  Anio
# 0                                       4253333  02  2015
# 1                                       4528299  03  2015
# 2                                       6171248  04  2015
# 3                                       5300402  05  2015
# 4                                       4709721  06  2015

# %% [markdown]
# Dado que en `FRONTUR 13864` los __Motivos principales__ que tenemos solo 'Negocio, motivos profesionales'	'Ocio, recreo y vacaciones' y 'Otros motivos' vamos a englobar el grupo de 'Visitas a familiares o amigos' en el grupo de 'Otros motivos'

# %%
df_pivot_12421['Otros motivos'] = df_pivot_12421['Otros motivos'] + df_pivot_12421['Visitas a familiares o amigos']
df_pivot_12421 = df_pivot_12421.drop('Visitas a familiares o amigos', axis=1)
df_pivot_12421.head()
# Out:
# Motivo principal  Periodo  Negocios y otros motivos profesionales  \
# 0                 2015M02                                 1501367
# 1                 2015M03                                 1604882
# 2                 2015M04                                 1553530
# 3                 2015M05                                 1690830
# 4                 2015M06                                 2152339
#
# Motivo principal  Ocio, recreo y vacaciones  Otros motivos     Total Mes  Anio
# 0                                 3527378.0      5105716.0  10134462  02  2015
# 1                                 4520604.0      5482707.0  11608193  03  2015
# 2                                 7546401.0      7236696.0  16336628  04  2015
# 3                                 6608010.0      6515460.0  14814300  05  2015
# 4                                 7623671.0      5829062.0  15605072  06  2015

# %%
df_pivot_12421.columns.values
# Out:
# array(['Periodo', 'Negocios y otros motivos profesionales',
#        'Ocio, recreo y vacaciones', 'Otros motivos', 'Total', 'Mes',
#        'Anio'], dtype=object)

# %%
nuevo_orden = ['Anio', 'Mes', 'Negocios y otros motivos profesionales',
       'Ocio, recreo y vacaciones', 'Otros motivos', 'Total']
df_pivot_12421 = df_pivot_12421[nuevo_orden]
df_pivot_12421
# Out:
# Motivo principal  Anio Mes  Negocios y otros motivos profesionales  \
# 0                 2015  02                                 1501367
# 1                 2015  03                                 1604882
# 2                 2015  04                                 1553530
# 3                 2015  05                                 1690830
# 4                 2015  06                                 2152339
# ..                 ...  ..                                     ...
# 114               2024  08                                  816337
# 115               2024  09                                 1500899
# 116               2024  10                                 1585018
# 117               2024  11                                 1446891
# 118               2024  12                                  917138
#
# Motivo principal  Ocio, recreo y vacaciones  Otros motivos     Total
# 0                                 3527378.0      5105716.0  10134462
# 1                                 4520604.0      5482707.0  11608193
# 2                                 7546401.0      7236696.0  16336628
# 3                                 6608010.0      6515460.0  14814300
# 4                                 7623671.0      5829062.0  15605072
# ..                                      ...            ...       ...
# 114                              16351105.0      7700172.0  24867614
# 115                               8694369.0      5905925.0  16101193
# 116                               5840034.0      5061278.0  12486330
# 117                               4963616.0      5151353.0  11561861
# 118                               5843167.0      7560712.0  14321016
#
# [119 rows x 6 columns]

# %%
df_pivot_12421.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119 entries, 0 to 118
# Data columns (total 6 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   Anio                                    119 non-null    object
#  1   Mes                                     119 non-null    object
#  2   Negocios y otros motivos profesionales  119 non-null    int64
#  3   Ocio, recreo y vacaciones               118 non-null    float64
#  4   Otros motivos                           118 non-null    float64
#  5   Total                                   119 non-null    int64
# dtypes: float64(2), int64(2), object(2)
# memory usage: 5.7+ KB

# %%
# convierto en int tmb el año y el mes
col_no = ['Anio', 'Mes']
df_pivot_12421[col_no] = df_pivot_12421[col_no].apply(pd.to_numeric, errors='coerce')
df_pivot_12421.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119 entries, 0 to 118
# Data columns (total 6 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   Anio                                    119 non-null    int64
#  1   Mes                                     119 non-null    int64
#  2   Negocios y otros motivos profesionales  119 non-null    int64
#  3   Ocio, recreo y vacaciones               118 non-null    float64
#  4   Otros motivos                           118 non-null    float64
#  5   Total                                   119 non-null    int64
# dtypes: float64(2), int64(4)
# memory usage: 5.7 KB

# %%
# ordenamos descendete anio, mes
df_pivot_12421 = df_pivot_12421.sort_values(by=['Anio', 'Mes'], ascending=[False, False])
df_pivot_12421
# Out:
# Motivo principal  Anio  Mes  Negocios y otros motivos profesionales  \
# 118               2024   12                                  917138
# 117               2024   11                                 1446891
# 116               2024   10                                 1585018
# 115               2024    9                                 1500899
# 114               2024    8                                  816337
# ..                 ...  ...                                     ...
# 4                 2015    6                                 2152339
# 3                 2015    5                                 1690830
# 2                 2015    4                                 1553530
# 1                 2015    3                                 1604882
# 0                 2015    2                                 1501367
#
# Motivo principal  Ocio, recreo y vacaciones  Otros motivos     Total
# 118                               5843167.0      7560712.0  14321016
# 117                               4963616.0      5151353.0  11561861
# 116                               5840034.0      5061278.0  12486330
# 115                               8694369.0      5905925.0  16101193
# 114                              16351105.0      7700172.0  24867614
# ..                                      ...            ...       ...
# 4                                 7623671.0      5829062.0  15605072
# 3                                 6608010.0      6515460.0  14814300
# 2                                 7546401.0      7236696.0  16336628
# 1                                 4520604.0      5482707.0  11608193
# 0                                 3527378.0      5105716.0  10134462
#
# [119 rows x 6 columns]

# %%
df_pivot_12421.to_csv('./data/ert_12421_clean.csv')

# %%
# TODO: borrar regitros diferencia respeto a FRONTUR 13864

# %% [markdown]
# #### 24919 [Viajes, pernocatciones, duracion media y gasto por tipo de destino principal](https://www.ine.es/jaxiT3/Tabla.htm?t=24919)

# %% [markdown]
# * Descripción: Datos sobre viajes realizados por los residentes en España, tanto dentro como fuera del país.
# * Variables: Número de viajes de residentes por mes, destino (interior o exterior), motivo del viaje, duración, gasto medio.

# %% [markdown]
# ![Turistas nacionales](./img/24919.png)

# %%
# Lectura con latin por los tildes de la cabecera
df_residentes = pd.read_csv("./data/24919.csv", sep=";", encoding='latin-1')
df_residentes.head()
# Out:
#   Tipo de destino Concepto turístico    Tipo de dato  Periodo        Total
# 0           Total             Viajes  Valor absoluto     2024  184.431.108
# 1           Total             Viajes  Valor absoluto     2023  185.895.163
# 2           Total             Viajes  Valor absoluto     2022  171.388.138
# 3           Total             Viajes  Valor absoluto     2021  142.893.461
# 4           Total             Viajes  Valor absoluto     2020  101.523.862

# %%
df_residentes.tail()
# Out:
#                Tipo de destino              Concepto turístico  \
# 355  A otra Comunidad Autónoma  Gasto medio diario por persona
# 356  A otra Comunidad Autónoma  Gasto medio diario por persona
# 357  A otra Comunidad Autónoma  Gasto medio diario por persona
# 358  A otra Comunidad Autónoma  Gasto medio diario por persona
# 359  A otra Comunidad Autónoma  Gasto medio diario por persona
#
#        Tipo de dato  Periodo  Total
# 355  Valor absoluto     2019  58,38
# 356  Valor absoluto     2018  56,93
# 357  Valor absoluto     2017  54,06
# 358  Valor absoluto     2016  52,16
# 359  Valor absoluto     2015  49,98

# %%
df_residentes['Tipo de destino'].unique()
# Out:
# array(['Total', 'Extranjera', 'España', 'Dentro de la Comunidad Autónoma',
#        'Dentro de la provincia', 'A otra Comunidad Autónoma'],
#       dtype=object)

# %%
df_residentes['Tipo de destino'].nunique()
# Out:
# 6

# %% [markdown]
# #### 15797 [Viajes, pernoctaciones y duración media por principales características de los viajes ETR](https://www.ine.es/jaxiT3/Tabla.htm?t=15797)

# %% [markdown]
# ![img](./img/15797.png)

# %%
# # TODO: limpiar caracteres raros
# df_residentes = pd.read_csv("./data/15797(1).csv", sep=";")
# df_residentes.head()

# %% [markdown]
# ### Webscrapping festivos España
#
# [Ver en detalle](./webScrapping.ipynb)
#
# [Calendarios laborales](https://www.calendarioslaborales.com)

# %% [markdown]
# ![img](./img/calendarios.PNG)

# %% [markdown]
# #### Calendario_festivos_15_25.csv

# %%
import pandas as pd
import numpy as np

# %%
df_calendar = pd.read_csv("./data/calendario_festivos_15_25.csv", index_col=0)
display('df_calendar.head()', 'df_calendar.tail()')
# Out:
# df_calendar.head()
#    dia    mes  anio             festivo provincia   comunidad    ambito
# 0    1  Enero  2015           Año nuevo     Alava  Pais Vasco  nacional
# 1    6  Enero  2015  Epifanía del Señor     Alava  Pais Vasco  nacional
# 2   19  Marzo  2015            San José     Alava  Pais Vasco  regional
# 3    2  Abril  2015        Jueves Santo     Alava  Pais Vasco  regional
# 4    3  Abril  2015       Viernes Santo     Alava  Pais Vasco  nacional
#
# df_calendar.tail()
#       dia        mes  anio                                festivo provincia  \
# 6274   12    Octubre  2025  Fiesta Nacional(se traslada al lunes)  Zaragoza
# 6275    1  Noviembre  2025                Día de Todos los Santos  Zaragoza
# 6276    6  Diciembre  2025        Día de la Constitución Española  Zaragoza
# 6277    8  Diciembre  2025                  Inmaculada Concepción  Zaragoza
# 6278   25  Diciembre  2025                                Navidad  Zaragoza
#
#      comunidad    ambito
# 6274    Aragon  regional
# 6275    Aragon  nacional
# 6276    Aragon  nacional
# 6277    Aragon  nacional
# 6278    Aragon  nacional

# %%
df_calendar.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6279 entries, 0 to 6278
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   dia        6279 non-null   int64
#  1   mes        6279 non-null   object
#  2   anio       6279 non-null   int64
#  3   festivo    6238 non-null   object
#  4   provincia  6279 non-null   object
#  5   comunidad  6279 non-null   object
#  6   ambito     6279 non-null   object
# dtypes: int64(2), object(5)
# memory usage: 392.4+ KB

# %%
df_calendar[df_calendar.festivo.isna()]

# %% [markdown]
# Los _missinngs_ resultan ser el día de "Día de Todos los Santos" en 2019 para todas las provincias. Actualizo campo y csv.

# %%
df_calendar.loc[df_calendar.festivo.isna(), 'festivo'] = 'Día de Todos los Santos'
df_calendar.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6279 entries, 0 to 6278
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   dia        6279 non-null   int64
#  1   mes        6279 non-null   object
#  2   anio       6279 non-null   int64
#  3   festivo    6279 non-null   object
#  4   provincia  6279 non-null   object
#  5   comunidad  6279 non-null   object
#  6   ambito     6279 non-null   object
# dtypes: int64(2), object(5)
# memory usage: 392.4+ KB

# %%
df_calendar.to_csv('./data/calendario_festivos_15_25.csv')

# %% [markdown]
# Índice de concentración festiva

# %%
# df_concentracion_festiva = 
df_calendar.groupby(['provincia', 'anio', 'mes'])['festivo'].count()
# Out:
# provincia  anio  mes
# Alava      2015  Abril        4
#                  Agosto       2
#                  Diciembre    2
#                  Enero        2
#                  Julio        1
#                              ..
# Zaragoza   2025  Enero        3
#                  Marzo        1
#                  Mayo         1
#                  Noviembre    1
#                  Octubre      1
# Name: festivo, Length: 3841, dtype: int64

# %%
df_concentracion_festiva = df_calendar.groupby(['provincia', 'anio', 'mes'])['festivo'].count()

# %%
df_concentracion_festiva.loc['Alava'][2019]
# Out:
# mes
# Abril        4
# Agosto       2
# Diciembre    2
# Enero        1
# Julio        1
# Marzo        1
# Mayo         1
# Noviembre    1
# Octubre      1
# Name: festivo, dtype: int64

# %% [markdown]
# ## H1 Se viaja más despúes de la _pandemia_? Viajes antes y después de la pandemia.
#     - En España, el número de viajes ha aumentado tras la pandemia (2020).

# %% [markdown]
# ## H2 Se viaja más por ocio que por trabajo? Motivos de viaje: _turismo_ vs _negocios_
#     - El turismo nacional de ocio ha aumentado más que los viajes por otros motivos (trabajo, estudios, etc.).
#     - Utilizar la variable «Motivo del viaje» en la ETR para segmentar.

# %% [markdown]
# ## H3 Influyen los festivos en el número de viajes? Las estaciones (tendencias _estacionales_)?

# %% [markdown]
# ## H4 Los españoles viajan más dentro de España o prefieren el extranejo después de la pandemia?

# %% [markdown]
# ## H5 El turismo internacional se ha recuperado más rápidamente que el nacional.
#     - Comprobar si los turistas extranjeros regresaron en mayor número o antes que los residentes nacionales.
#     - Comparar la evolución año a año desde 2020.

# %% [markdown]
# ## H6 Tras la pandemia, los destinos costeros se han convertido en la opción preferida.
#     - Analizar por comunidad autónoma o provincia en ETR o FRONTUR si hay más viajes hacia zonas como Andalucía, Comunidad Valenciana, Canarias, Islas Baleares, etc.

# %% [markdown]
# ## H7 Ciertas comunidades autónomas han experimentado un mayor crecimiento turístico.

# %% [markdown]
# ### Webscrapping festivos España
#
# [Ver en detalle](./webScrapping.ipynb)
#
# [Calendarios laborales](https://www.calendarioslaborales.com)

# %% [markdown]
# ![img](./img/calendarios.PNG)
